# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# import requests libraries
import requests
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# 3. Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# 4. Identify the nearest city for each latitude and longitude combination using the citipy module.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
#Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city to discover how to index through the JSON data
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 72.57,
#   'feels_like': 72.91,
#   'temp_min': 68.22,
#   'temp_max': 75.65,
#   'pressure': 1013,
#   'humidity': 72},
#  'visibility': 10000,
#  'wind': {'speed': 5.99, 'deg': 119, 'gust': 10},
#  'clouds': {'all': 13},
#  'dt': 1657765037,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1657703938,
#   'sunset': 1657758035},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]  
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # 5. Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        
#6. Retrieve the following information from the API call: Latitude and longitude, Maximum temperature
# Percent humidity, Percent cloudiness, Wind speed, Weather description (for example, clouds, fog, light rain, clear sky)
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_description,
                          "Date": city_date})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | saint-philippe
# Processing Record 2 of Set 16 | burica
# City not found. Skipping...
# Processing Record 3 of Set 16 | chuy
# Processing Record 4 of Set 16 | angoche
# Processing Record 5 of Set 16 | punta arenas
# Processing Record 6 of Set 16 | hope
# Processing Record 7 of Set 16 | plouzane
# Processing Record 8 of Set 16 | port alfred
# Processing Record 9 of Set 16 | vila velha
# Processing Record 10 of Set 16 | fort-shevchenko
# Processing Record 11 of Set 16 | lasa
# Processing Record 12 of Set 16 | victoria
# Processing Record 13 of Set 16 | lingao
# Processing Record 14 of Set 16 | bengkulu
# Processing Record 15 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 16 | cidreira
# Processing Record 18 of Set 16 | sisimiut
# Processing Record 19 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 16 | kenai
# Processing Record 21 of Set 16 | castro
# Processing Record 22 of Set 16 | sabang
# Processing Record 23 of Set 16 | dudinka
# Processing Record 24 of Set 16 | pevek
# Processing Record 25 of Set 16 | hay river
# Processing Record 26 of Set 16 | new norfolk
# Processing Record 27 of Set 16 | deputatskiy
# Processing Record 28 of Set 16 | ushuaia
# Processing Record 29 of Set 16 | mecca
# Processing Record 30 of Set 16 | marsh harbour
# Processing Record 31 of Set 16 | bourail
# Processing Record 32 of Set 16 | nhulunbuy
# Processing Record 33 of Set 16 | mataura
# Processing Record 34 of Set 16 | rikitea
# Processing Record 35 of Set 16 | wewak
# Processing Record 36 of Set 16 | cape town
# Processing Record 37 of Set 16 | the valley
# Processing Record 38 of Set 16 | carlyle
# Processing Record 39 of Set 16 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 16 | chokurdakh
# Processing Record 41 of Set 16 | gimli
# Processing Record 42 of Set 16 | gazni
# City not found. Skipping...
# Processing Record 43 of Set 16 | bowen
# Processing Record 44 of Set 16 | meulaboh
# Processing Record 45 of Set 16 | yaan
# Processing Record 46 of Set 16 | east london
# Processing Record 47 of Set 16 | hilo
# Processing Record 48 of Set 16 | young
# Processing Record 49 of Set 16 | port pirie
# Processing Record 50 of Set 16 | caravelas
# Processing Record 1 of Set 17 | brae
# Processing Record 2 of Set 17 | coihaique
# Processing Record 3 of Set 17 | bogo
# Processing Record 4 of Set 17 | grand gaube
# Processing Record 5 of Set 17 | atuona
# Processing Record 6 of Set 17 | kaitangata
# Processing Record 7 of Set 17 | vaini
# Processing Record 8 of Set 17 | arraial do cabo
# Processing Record 9 of Set 17 | norman wells
# Processing Record 10 of Set 17 | qaanaaq
# Processing Record 11 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 17 | uyuni
# Processing Record 13 of Set 17 | bereda
# Processing Record 14 of Set 17 | hasaki
# Processing Record 15 of Set 17 | yellowknife
# Processing Record 16 of Set 17 | beyneu
# Processing Record 17 of Set 17 | pyay
# Processing Record 18 of Set 17 | formoso do araguaia
# City not found. Skipping...
# Processing Record 19 of Set 17 | butaritari
# Processing Record 20 of Set 17 | portland
# Processing Record 21 of Set 17 | port elizabeth
# Processing Record 22 of Set 17 | jiayuguan
# Processing Record 23 of Set 17 | jamestown
# Processing Record 24 of Set 17 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 17 | zhaotong
# Processing Record 26 of Set 17 | wuning
# Processing Record 27 of Set 17 | broome
# Processing Record 28 of Set 17 | pascagoula
# Processing Record 29 of Set 17 | bredasdorp
# Processing Record 30 of Set 17 | paracuru
# Processing Record 31 of Set 17 | aykhal
# Processing Record 32 of Set 17 | saldanha
# Processing Record 33 of Set 17 | yulara
# Processing Record 34 of Set 17 | ponta do sol
# Processing Record 35 of Set 17 | rundu
# Processing Record 36 of Set 17 | college
# Processing Record 37 of Set 17 | dingle
# Processing Record 38 of Set 17 | bac lieu
# Processing Record 39 of Set 17 | hermanus
# Processing Record 40 of Set 17 | grindavik
# Processing Record 41 of Set 17 | tuktoyaktuk
# Processing Record 42 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 17 | sadon
# Processing Record 44 of Set 17 | port lincoln
# Processing Record 45 of Set 17 | boa vista
# Processing Record 46 of Set 17 | batemans bay
# Processing Record 47 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 17 | buckeye
# Processing Record 49 of Set 17 | leningradskiy
# Processing Record 50 of Set 17 | santa maria da vitoria
# Processing Record 1 of Set 18 | thompson
# Processing Record 2 of Set 18 | pedernales
# Processing Record 3 of Set 18 | kupang
# Processing Record 4 of Set 18 | shelburne
# Processing Record 5 of Set 18 | pozo colorado
# Processing Record 6 of Set 18 | venado tuerto
# Processing Record 7 of Set 18 | farafangana
# Processing Record 8 of Set 18 | mandawar
# Processing Record 9 of Set 18 | mahebourg
# Processing Record 10 of Set 18 | san cristobal
# Processing Record 11 of Set 18 | hobart
# Processing Record 12 of Set 18 | port hardy
# Processing Record 13 of Set 18 | puerto madryn
# Processing Record 14 of Set 18 | lauro muller
# Processing Record 15 of Set 18 | ayotzintepec
# Processing Record 16 of Set 18 | cayenne
# Processing Record 17 of Set 18 | avarua
# Processing Record 18 of Set 18 | silver city
# Processing Record 19 of Set 18 | songjianghe
# Processing Record 20 of Set 18 | jaumave
# Processing Record 21 of Set 18 | progreso
# Processing Record 22 of Set 18 | auchi
# Processing Record 23 of Set 18 | longyearbyen
# Processing Record 24 of Set 18 | ketchikan
# Processing Record 25 of Set 18 | arica
# Processing Record 26 of Set 18 | tanshui
# City not found. Skipping...
# Processing Record 27 of Set 18 | palmer
# Processing Record 28 of Set 18 | bluff
# Processing Record 29 of Set 18 | hobyo
# Processing Record 30 of Set 18 | albany
# Processing Record 31 of Set 18 | provideniya
# Processing Record 32 of Set 18 | taksimo
# Processing Record 33 of Set 18 | geraldton
# Processing Record 34 of Set 18 | ayan
# Processing Record 35 of Set 18 | esperance
# Processing Record 36 of Set 18 | kavaje
# Processing Record 37 of Set 18 | husavik
# Processing Record 38 of Set 18 | upernavik
# Processing Record 39 of Set 18 | nouakchott
# Processing Record 40 of Set 18 | ilulissat
# Processing Record 41 of Set 18 | goksun
# Processing Record 42 of Set 18 | mana
# Processing Record 43 of Set 18 | maldonado
# Processing Record 44 of Set 18 | vila franca do campo
# Processing Record 45 of Set 18 | maghama
# City not found. Skipping...
# Processing Record 46 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 18 | kutum
# Processing Record 48 of Set 18 | kloulklubed
# Processing Record 49 of Set 18 | busselton
# Processing Record 50 of Set 18 | faanui
# Processing Record 1 of Set 19 | srandakan
# Processing Record 2 of Set 19 | san quintin
# Processing Record 3 of Set 19 | saint-joseph
# Processing Record 4 of Set 19 | mantua
# Processing Record 5 of Set 19 | morondava
# Processing Record 6 of Set 19 | kamenka
# Processing Record 7 of Set 19 | cabo san lucas
# Processing Record 8 of Set 19 | tasiilaq
# Processing Record 9 of Set 19 | narkanda
# Processing Record 10 of Set 19 | pangnirtung
# Processing Record 11 of Set 19 | nikolskoye
# Processing Record 12 of Set 19 | bethel
# Processing Record 13 of Set 19 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 19 | khatanga
# Processing Record 15 of Set 19 | puerto ayora
# Processing Record 16 of Set 19 | chillicothe
# Processing Record 17 of Set 19 | bongaree
# Processing Record 18 of Set 19 | alyangula
# Processing Record 19 of Set 19 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 19 | kapaa
# Processing Record 21 of Set 19 | winnipeg
# Processing Record 22 of Set 19 | boysun
# Processing Record 23 of Set 19 | saint george
# Processing Record 24 of Set 19 | paraiso
# Processing Record 25 of Set 19 | stornoway
# Processing Record 26 of Set 19 | yarada
# Processing Record 27 of Set 19 | laguna
# Processing Record 28 of Set 19 | banamba
# Processing Record 29 of Set 19 | churapcha
# Processing Record 30 of Set 19 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 19 | los andes
# Processing Record 32 of Set 19 | kahului
# Processing Record 33 of Set 19 | denpasar
# Processing Record 34 of Set 19 | nago
# Processing Record 35 of Set 19 | sar-e pul
# Processing Record 36 of Set 19 | sindand
# City not found. Skipping...
# Processing Record 37 of Set 19 | gardan diwal
# City not found. Skipping...
# Processing Record 38 of Set 19 | aleysk
# Processing Record 39 of Set 19 | tiksi
# Processing Record 40 of Set 19 | evensk
# Processing Record 41 of Set 19 | ancud
# Processing Record 42 of Set 19 | kropotkin
# Processing Record 43 of Set 19 | ossora
# Processing Record 44 of Set 19 | lebu
# Processing Record 45 of Set 19 | nantucket
# Processing Record 46 of Set 19 | paradwip
# City not found. Skipping...
# Processing Record 47 of Set 19 | almaznyy
# Processing Record 48 of Set 19 | richards bay
# Processing Record 49 of Set 19 | iqaluit
# Processing Record 50 of Set 19 | provins
# Processing Record 1 of Set 20 | lompoc
# Processing Record 2 of Set 20 | barrow
# Processing Record 3 of Set 20 | codrington
# Processing Record 4 of Set 20 | naze
# Processing Record 5 of Set 20 | carupano
# Processing Record 6 of Set 20 | nishihara
# Processing Record 7 of Set 20 | fort nelson
# Processing Record 8 of Set 20 | ahipara
# Processing Record 9 of Set 20 | dalianwan
# Processing Record 10 of Set 20 | bonfim
# Processing Record 11 of Set 20 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 20 | kiboga
# Processing Record 13 of Set 20 | alofi
# Processing Record 14 of Set 20 | dengzhou
# Processing Record 15 of Set 20 | namibe
# Processing Record 16 of Set 20 | bumba
# Processing Record 17 of Set 20 | torbay
# Processing Record 18 of Set 20 | springfield
# Processing Record 19 of Set 20 | aden
# Processing Record 20 of Set 20 | pattani
# Processing Record 21 of Set 20 | gravdal
# Processing Record 22 of Set 20 | luderitz
# Processing Record 23 of Set 20 | kununurra
# Processing Record 24 of Set 20 | dikson
# Processing Record 25 of Set 20 | pochutla
# Processing Record 26 of Set 20 | skibbereen
# Processing Record 27 of Set 20 | tansen
# Processing Record 28 of Set 20 | namatanai
# Processing Record 29 of Set 20 | carnarvon
# Processing Record 30 of Set 20 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 20 | shimoda
# Processing Record 32 of Set 20 | taoudenni
# Processing Record 33 of Set 20 | santa cruz
# Processing Record 34 of Set 20 | alugan
# Processing Record 35 of Set 20 | aklavik
# Processing Record 36 of Set 20 | altamont
# Processing Record 37 of Set 20 | kodiak
# Processing Record 38 of Set 20 | gornopravdinsk
# Processing Record 39 of Set 20 | taraz
# Processing Record 40 of Set 20 | alice springs
# Processing Record 41 of Set 20 | karratha
# Processing Record 42 of Set 20 | georgetown
# Processing Record 43 of Set 20 | sobolevo
# Processing Record 44 of Set 20 | opuwo
# Processing Record 45 of Set 20 | thinadhoo
# Processing Record 46 of Set 20 | lavrentiya
# Processing Record 47 of Set 20 | hithadhoo
# Processing Record 48 of Set 20 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 20 | kruisfontein
# Processing Record 50 of Set 20 | lata
# Processing Record 1 of Set 21 | general roca
# Processing Record 2 of Set 21 | kingaroy
# Processing Record 3 of Set 21 | we
# City not found. Skipping...
# Processing Record 4 of Set 21 | hartlepool
# Processing Record 5 of Set 21 | gimbi
# Processing Record 6 of Set 21 | wawa
# Processing Record 7 of Set 21 | moissala
# Processing Record 8 of Set 21 | saskylakh
# Processing Record 9 of Set 21 | puerto escondido
# Processing Record 10 of Set 21 | krasnoselkup
# Processing Record 11 of Set 21 | mar del plata
# Processing Record 12 of Set 21 | narsaq
# Processing Record 13 of Set 21 | isangel
# Processing Record 14 of Set 21 | baiyin
# Processing Record 15 of Set 21 | sao jose da coroa grande
# Processing Record 16 of Set 21 | lorengau
# Processing Record 17 of Set 21 | mandurah
# Processing Record 18 of Set 21 | arkhipo-osipovka
# Processing Record 19 of Set 21 | ghanzi
# Processing Record 20 of Set 21 | leninskoye
# Processing Record 21 of Set 21 | turukhansk
# Processing Record 22 of Set 21 | katsuura
# Processing Record 23 of Set 21 | guayaramerin
# Processing Record 24 of Set 21 | tombouctou
# Processing Record 25 of Set 21 | juigalpa
# Processing Record 26 of Set 21 | yuncheng
# Processing Record 27 of Set 21 | sur
# Processing Record 28 of Set 21 | mumford
# Processing Record 29 of Set 21 | orcopampa
# Processing Record 30 of Set 21 | mogochin
# City not found. Skipping...
# Processing Record 31 of Set 21 | susangerd
# Processing Record 32 of Set 21 | srednekolymsk
# Processing Record 33 of Set 21 | kirakira
# Processing Record 34 of Set 21 | capitan bado
# Processing Record 35 of Set 21 | sioux lookout
# Processing Record 36 of Set 21 | khowai
# Processing Record 37 of Set 21 | lodja
# Processing Record 38 of Set 21 | coquimbo
# Processing Record 39 of Set 21 | marabba
# Processing Record 40 of Set 21 | tarut
# Processing Record 41 of Set 21 | port moresby
# Processing Record 42 of Set 21 | ust-ordynskiy
# Processing Record 43 of Set 21 | san lawrenz
# Processing Record 44 of Set 21 | peto
# Processing Record 45 of Set 21 | mmabatho
# Processing Record 46 of Set 21 | fortuna
# Processing Record 47 of Set 21 | cabedelo
# Processing Record 48 of Set 21 | tessalit
# Processing Record 49 of Set 21 | los llanos de aridane
# Processing Record 50 of Set 21 | madaoua
# Processing Record 1 of Set 22 | tahta
# Processing Record 2 of Set 22 | qaqortoq
# Processing Record 3 of Set 22 | port blair
# Processing Record 4 of Set 22 | kirensk
# Processing Record 5 of Set 22 | pampa
# Processing Record 6 of Set 22 | hawera
# Processing Record 7 of Set 22 | marzuq
# Processing Record 8 of Set 22 | pisco
# Processing Record 9 of Set 22 | ribeira grande
# Processing Record 10 of Set 22 | sola
# Processing Record 11 of Set 22 | tadine
# Processing Record 12 of Set 22 | gizo
# Processing Record 13 of Set 22 | aromashevo
# Processing Record 14 of Set 22 | balkhash
# Processing Record 15 of Set 22 | ballina
# Processing Record 16 of Set 22 | radhanpur
# Processing Record 17 of Set 22 | sampit
# Processing Record 18 of Set 22 | zhob
# Processing Record 19 of Set 22 | vestmannaeyjar
# Processing Record 20 of Set 22 | ulaangom
# Processing Record 21 of Set 22 | ambodifototra
# City not found. Skipping...
# Processing Record 22 of Set 22 | haines junction
# Processing Record 23 of Set 22 | sao gabriel da cachoeira
# Processing Record 24 of Set 22 | bathsheba
# Processing Record 25 of Set 22 | ponta delgada
# Processing Record 26 of Set 22 | mount isa
# Processing Record 27 of Set 22 | south yuba city
# Processing Record 28 of Set 22 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 22 | nalut
# Processing Record 30 of Set 22 | jalu
# Processing Record 31 of Set 22 | cherskiy
# Processing Record 32 of Set 22 | talnakh
# Processing Record 33 of Set 22 | starkville
# Processing Record 34 of Set 22 | nabire
# Processing Record 35 of Set 22 | nagato
# Processing Record 36 of Set 22 | andujar
# Processing Record 37 of Set 22 | hofn
# Processing Record 38 of Set 22 | escanaba
# Processing Record 39 of Set 22 | lake havasu city
# Processing Record 40 of Set 22 | inhambane
# Processing Record 41 of Set 22 | airai
# Processing Record 42 of Set 22 | bilma
# Processing Record 43 of Set 22 | prainha
# Processing Record 44 of Set 22 | bonavista
# Processing Record 45 of Set 22 | gurgan
# City not found. Skipping...
# Processing Record 46 of Set 22 | paamiut
# Processing Record 47 of Set 22 | kalmunai
# Processing Record 48 of Set 22 | ilebo
# Processing Record 49 of Set 22 | oktyabrskoye
# Processing Record 50 of Set 22 | santa rosa
# Processing Record 1 of Set 23 | dunedin
# Processing Record 2 of Set 23 | mentok
# City not found. Skipping...
# Processing Record 3 of Set 23 | sechura
# Processing Record 4 of Set 23 | valparaiso
# Processing Record 5 of Set 23 | comodoro rivadavia
# Processing Record 6 of Set 23 | san patricio
# Processing Record 7 of Set 23 | san pablo
# Processing Record 8 of Set 23 | sabha
# Processing Record 9 of Set 23 | galle
# Processing Record 10 of Set 23 | yatou
# Processing Record 11 of Set 23 | henties bay
# Processing Record 12 of Set 23 | margate
# Processing Record 13 of Set 23 | atar
# Processing Record 14 of Set 23 | rumford
# Processing Record 15 of Set 23 | cockburn town
# Processing Record 16 of Set 23 | general pico
# Processing Record 17 of Set 23 | haimen
# Processing Record 18 of Set 23 | tilichiki
# Processing Record 19 of Set 23 | khani
# Processing Record 20 of Set 23 | asau
# Processing Record 21 of Set 23 | vaitape
# Processing Record 22 of Set 23 | zhigansk
# Processing Record 23 of Set 23 | hambantota
# Processing Record 24 of Set 23 | porosozero
# Processing Record 25 of Set 23 | gat
# Processing Record 26 of Set 23 | sahuaripa
# Processing Record 27 of Set 23 | bonthe
# Processing Record 28 of Set 23 | jiaocheng
# Processing Record 29 of Set 23 | west bay
# Processing Record 30 of Set 23 | ambulu
# Processing Record 31 of Set 23 | pecos
# Processing Record 32 of Set 23 | boende
# Processing Record 33 of Set 23 | nacala
# Processing Record 34 of Set 23 | fairbanks
# Processing Record 35 of Set 23 | awbari
# Processing Record 36 of Set 23 | bay roberts
# Processing Record 37 of Set 23 | kimbe
# Processing Record 38 of Set 23 | manoel urbano
# Processing Record 39 of Set 23 | solano
# Processing Record 40 of Set 23 | santa ana
# Processing Record 41 of Set 23 | ca mau
# Processing Record 42 of Set 23 | puerto baquerizo moreno
# Processing Record 43 of Set 23 | teknaf
# Processing Record 44 of Set 23 | tura
# Processing Record 45 of Set 23 | tam ky
# Processing Record 46 of Set 23 | karkaralinsk
# City not found. Skipping...
# Processing Record 47 of Set 23 | brainerd
# Processing Record 48 of Set 23 | bokspits
# City not found. Skipping...
# Processing Record 49 of Set 23 | prince albert
# Processing Record 50 of Set 23 | riyadh
# Processing Record 1 of Set 24 | tuatapere
# Processing Record 2 of Set 24 | walvis bay
# Processing Record 3 of Set 24 | agutaya
# Processing Record 4 of Set 24 | clyde river
# Processing Record 5 of Set 24 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 24 | westpunt
# City not found. Skipping...
# Processing Record 7 of Set 24 | de-kastri
# Processing Record 8 of Set 24 | ati
# Processing Record 9 of Set 24 | merauke
# Processing Record 10 of Set 24 | la antigua
# Processing Record 11 of Set 24 | presidencia roque saenz pena
# Processing Record 12 of Set 24 | tsiroanomandidy
# Processing Record 13 of Set 24 | labuan
# Processing Record 14 of Set 24 | muros
# Processing Record 15 of Set 24 | hidalgo
# Processing Record 16 of Set 24 | severo-kurilsk
# Processing Record 17 of Set 24 | timiryazevskoye
# Processing Record 18 of Set 24 | vao
# Processing Record 19 of Set 24 | acapulco
# Processing Record 20 of Set 24 | sayat
# Processing Record 21 of Set 24 | lumphat
# Processing Record 22 of Set 24 | mercedes
# Processing Record 23 of Set 24 | shache
# Processing Record 24 of Set 24 | umm kaddadah
# Processing Record 25 of Set 24 | alice
# Processing Record 26 of Set 24 | severnyy
# Processing Record 27 of Set 24 | mehamn
# Processing Record 28 of Set 24 | moranbah
# Processing Record 29 of Set 24 | rioja
# Processing Record 30 of Set 24 | crossfield
# Processing Record 31 of Set 24 | novyy urengoy
# Processing Record 32 of Set 24 | yar-sale
# Processing Record 33 of Set 24 | kuytun
# Processing Record 34 of Set 24 | neepawa
# Processing Record 35 of Set 24 | vardo
# Processing Record 36 of Set 24 | acuna
# City not found. Skipping...
# Processing Record 37 of Set 24 | rio gallegos
# Processing Record 38 of Set 24 | baghdad
# Processing Record 39 of Set 24 | sharan
# Processing Record 40 of Set 24 | tiznit
# Processing Record 41 of Set 24 | san ignacio
# Processing Record 42 of Set 24 | agucadoura
# Processing Record 43 of Set 24 | yerbogachen
# Processing Record 44 of Set 24 | bambous virieux
# Processing Record 45 of Set 24 | iwanai
# Processing Record 46 of Set 24 | bowling green
# Processing Record 47 of Set 24 | gewane
# Processing Record 48 of Set 24 | north bend
# Processing Record 49 of Set 24 | usoke
# Processing Record 50 of Set 24 | conceicao do araguaia
# Processing Record 1 of Set 25 | baykit
# Processing Record 2 of Set 25 | necochea
# Processing Record 3 of Set 25 | kapit
# Processing Record 4 of Set 25 | vytegra
# Processing Record 5 of Set 25 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 25 | taltal
# Processing Record 7 of Set 25 | cotonou
# Processing Record 8 of Set 25 | mandera
# Processing Record 9 of Set 25 | biltine
# Processing Record 10 of Set 25 | kribi
# Processing Record 11 of Set 25 | sao joao da barra
# Processing Record 12 of Set 25 | qasigiannguit
# Processing Record 13 of Set 25 | banepa
# Processing Record 14 of Set 25 | soe
# Processing Record 15 of Set 25 | mezen
# Processing Record 16 of Set 25 | llangefni
# Processing Record 17 of Set 25 | keti bandar
# Processing Record 18 of Set 25 | kisiwani
# Processing Record 19 of Set 25 | shingu
# Processing Record 20 of Set 25 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 25 | ituni
# City not found. Skipping...
# Processing Record 22 of Set 25 | svetlyy
# Processing Record 23 of Set 25 | hovd
# Processing Record 24 of Set 25 | touros
# Processing Record 25 of Set 25 | arkhangelsk
# Processing Record 26 of Set 25 | shenjiamen
# Processing Record 27 of Set 25 | kavaratti
# Processing Record 28 of Set 25 | bambanglipuro
# Processing Record 29 of Set 25 | mitu
# Processing Record 30 of Set 25 | takoradi
# Processing Record 31 of Set 25 | khonuu
# City not found. Skipping...
# Processing Record 32 of Set 25 | oussouye
# Processing Record 33 of Set 25 | lazurne
# Processing Record 34 of Set 25 | kondinskoye
# Processing Record 35 of Set 25 | sayaxche
# Processing Record 36 of Set 25 | northam
# Processing Record 37 of Set 25 | mokhsogollokh
# Processing Record 38 of Set 25 | constitucion
# Processing Record 39 of Set 25 | nanortalik
# Processing Record 40 of Set 25 | tagusao
# Processing Record 41 of Set 25 | chapais
# Processing Record 42 of Set 25 | port macquarie
# Processing Record 43 of Set 25 | whitehorse
# Processing Record 44 of Set 25 | khandwa
# Processing Record 45 of Set 25 | pointe michel
# Processing Record 46 of Set 25 | williams lake
# Processing Record 47 of Set 25 | itarema
# Processing Record 48 of Set 25 | boyolangu
# Processing Record 49 of Set 25 | baherden
# Processing Record 50 of Set 25 | cap malheureux
# Processing Record 1 of Set 26 | berezovyy
# Processing Record 2 of Set 26 | ngunguru
# Processing Record 3 of Set 26 | kismayo
# Processing Record 4 of Set 26 | horsham
# Processing Record 5 of Set 26 | hamilton
# Processing Record 6 of Set 26 | avera
# Processing Record 7 of Set 26 | manggar
# Processing Record 8 of Set 26 | khandbari
# Processing Record 9 of Set 26 | yeysk
# Processing Record 10 of Set 26 | jijiga
# Processing Record 11 of Set 26 | mogadishu
# Processing Record 12 of Set 26 | kazalinsk
# City not found. Skipping...
# Processing Record 13 of Set 26 | sorland
# Processing Record 14 of Set 26 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 26 | buloh kasap
# Processing Record 16 of Set 26 | tomari
# Processing Record 17 of Set 26 | waipawa
# Processing Record 18 of Set 26 | nouadhibou
# Processing Record 19 of Set 26 | bundaberg
# Processing Record 20 of Set 26 | lircay
# Processing Record 21 of Set 26 | aranos
# Processing Record 22 of Set 26 | gualeguay
# Processing Record 23 of Set 26 | mayo
# Processing Record 24 of Set 26 | mitsamiouli
# Processing Record 25 of Set 26 | ntungamo
# Processing Record 26 of Set 26 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 26 | banda aceh
# Processing Record 28 of Set 26 | ravar
# Processing Record 29 of Set 26 | ambovombe
# Processing Record 30 of Set 26 | beringovskiy
# Processing Record 31 of Set 26 | hualmay
# Processing Record 32 of Set 26 | kangasala
# Processing Record 33 of Set 26 | tulum
# Processing Record 34 of Set 26 | samarai
# Processing Record 35 of Set 26 | la ronge
# Processing Record 36 of Set 26 | goderich
# Processing Record 37 of Set 26 | mega
# Processing Record 38 of Set 26 | qostanay
# Processing Record 39 of Set 26 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 26 | dubbo
# Processing Record 41 of Set 26 | chancay
# Processing Record 42 of Set 26 | mossendjo
# Processing Record 43 of Set 26 | nizhneudinsk
# Processing Record 44 of Set 26 | ulagan
# Processing Record 45 of Set 26 | aldan
# Processing Record 46 of Set 26 | arlit
# Processing Record 47 of Set 26 | zeewolde
# Processing Record 48 of Set 26 | fukue
# Processing Record 49 of Set 26 | tupancireta
# Processing Record 50 of Set 26 | nakhon thai
# Processing Record 1 of Set 27 | bella union
# Processing Record 2 of Set 27 | santa ines
# Processing Record 3 of Set 27 | barrhead
# Processing Record 4 of Set 27 | joshimath
# Processing Record 5 of Set 27 | puerto suarez
# Processing Record 6 of Set 27 | pacific grove
# Processing Record 7 of Set 27 | alpena
# Processing Record 8 of Set 27 | quatre cocos
# Processing Record 9 of Set 27 | toungoo
# City not found. Skipping...
# Processing Record 10 of Set 27 | kenora
# Processing Record 11 of Set 27 | buraydah
# Processing Record 12 of Set 27 | guerrero negro
# Processing Record 13 of Set 27 | lekoni
# Processing Record 14 of Set 27 | sekovici
# Processing Record 15 of Set 27 | high level
# Processing Record 16 of Set 27 | kalabo
# Processing Record 17 of Set 27 | tharad
# Processing Record 18 of Set 27 | kandrian
# Processing Record 19 of Set 27 | flinders
# Processing Record 20 of Set 27 | chunhuhub
# Processing Record 21 of Set 27 | wau
# Processing Record 22 of Set 27 | kattivakkam
# Processing Record 23 of Set 27 | launceston
# Processing Record 24 of Set 27 | aguimes
# Processing Record 25 of Set 27 | luceville
# City not found. Skipping...
# Processing Record 26 of Set 27 | tocopilla
# Processing Record 27 of Set 27 | pendra
# Processing Record 28 of Set 27 | havoysund
# Processing Record 29 of Set 27 | nichinan
# Processing Record 30 of Set 27 | ninotsminda
# Processing Record 31 of Set 27 | miedzyrzec podlaski
# Processing Record 32 of Set 27 | okhotsk
# Processing Record 33 of Set 27 | aloleng
# Processing Record 34 of Set 27 | beloha
# Processing Record 35 of Set 27 | shubarshi
# Processing Record 36 of Set 27 | fevralsk
# City not found. Skipping...
# Processing Record 37 of Set 27 | sao filipe
# Processing Record 38 of Set 27 | wagar
# Processing Record 39 of Set 27 | charters towers
# Processing Record 40 of Set 27 | ribeira brava
# Processing Record 41 of Set 27 | ixtapa
# Processing Record 42 of Set 27 | serrinha
# Processing Record 43 of Set 27 | shitkino
# Processing Record 44 of Set 27 | komsomolskiy
# Processing Record 45 of Set 27 | maniitsoq
# Processing Record 46 of Set 27 | manali
# Processing Record 47 of Set 27 | beamsville
# Processing Record 48 of Set 27 | daru
# Processing Record 49 of Set 27 | wattegama
# Processing Record 50 of Set 27 | saint-georges
# Processing Record 1 of Set 28 | tromso
# Processing Record 2 of Set 28 | den helder
# Processing Record 3 of Set 28 | hadishahr
# Processing Record 4 of Set 28 | benghazi
# Processing Record 5 of Set 28 | drabiv
# Processing Record 6 of Set 28 | nanzhou
# Processing Record 7 of Set 28 | pareora
# Processing Record 8 of Set 28 | batesville
# Processing Record 9 of Set 28 | yakeshi
# Processing Record 10 of Set 28 | harper
# Processing Record 11 of Set 28 | ndele
# Processing Record 12 of Set 28 | huarmey
# Processing Record 13 of Set 28 | kisangani
# Processing Record 14 of Set 28 | huanren
# Processing Record 15 of Set 28 | talcahuano
# Processing Record 16 of Set 28 | axim
# Processing Record 17 of Set 28 | yola
# Processing Record 18 of Set 28 | kurim
# Processing Record 19 of Set 28 | usinsk
# Processing Record 20 of Set 28 | micheweni
# Processing Record 21 of Set 28 | nyurba
# Processing Record 22 of Set 28 | qianan
# Processing Record 23 of Set 28 | rennes
# Processing Record 24 of Set 28 | kalaleh
# Processing Record 25 of Set 28 | karamay
# City not found. Skipping...
# Processing Record 26 of Set 28 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 27 of Set 28 | nedryhayliv
# Processing Record 28 of Set 28 | izhma
# Processing Record 29 of Set 28 | teluk nibung
# Processing Record 30 of Set 28 | mandal
# Processing Record 31 of Set 28 | maturin
# Processing Record 32 of Set 28 | vila
# Processing Record 33 of Set 28 | flers
# Processing Record 34 of Set 28 | rorvik
# Processing Record 35 of Set 28 | kholodnyy
# Processing Record 36 of Set 28 | sidi ali
# Processing Record 37 of Set 28 | manokwari
# Processing Record 38 of Set 28 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 28 | dukat
# Processing Record 40 of Set 28 | santa isabel do rio negro
# Processing Record 41 of Set 28 | vianopolis
# Processing Record 42 of Set 28 | kinshasa
# Processing Record 43 of Set 28 | shihezi
# Processing Record 44 of Set 28 | mehriz
# Processing Record 45 of Set 28 | manohar thana
# Processing Record 46 of Set 28 | ambilobe
# Processing Record 47 of Set 28 | verkhnyaya inta
# Processing Record 48 of Set 28 | khuzhir
# Processing Record 49 of Set 28 | padre paraiso
# Processing Record 50 of Set 28 | amazar
# Processing Record 1 of Set 29 | sembakung
# Processing Record 2 of Set 29 | sayyan
# Processing Record 3 of Set 29 | verkhnetulomskiy
# Processing Record 4 of Set 29 | horta
# Processing Record 5 of Set 29 | sovetskiy
# Processing Record 6 of Set 29 | sokoni
# Processing Record 7 of Set 29 | parakai
# Processing Record 8 of Set 29 | illapel
# Processing Record 9 of Set 29 | tabialan
# City not found. Skipping...
# Processing Record 10 of Set 29 | afsin
# Processing Record 11 of Set 29 | bandarbeyla
# Processing Record 12 of Set 29 | roebourne
# Processing Record 13 of Set 29 | riverton
# Processing Record 14 of Set 29 | villeneuve-sur-lot
# Processing Record 15 of Set 29 | nuuk
# Processing Record 16 of Set 29 | karauzyak
# City not found. Skipping...
# Processing Record 17 of Set 29 | severodvinsk
# Processing Record 18 of Set 29 | auki
# Processing Record 19 of Set 29 | vitoria da conquista
# Processing Record 20 of Set 29 | vestmanna
# Processing Record 21 of Set 29 | yaring
# Processing Record 22 of Set 29 | atambua
# Processing Record 23 of Set 29 | el alto
# Processing Record 24 of Set 29 | tooele
# Processing Record 25 of Set 29 | umm lajj
# Processing Record 26 of Set 29 | nava
# Processing Record 27 of Set 29 | jabiru
# City not found. Skipping...
# Processing Record 28 of Set 29 | gurskoye
# City not found. Skipping...
# Processing Record 29 of Set 29 | mlawa
# Processing Record 30 of Set 29 | jasper
# Processing Record 31 of Set 29 | bagenalstown
# Processing Record 32 of Set 29 | kolda
# Processing Record 33 of Set 29 | gweta
# Processing Record 34 of Set 29 | wuhu
# Processing Record 35 of Set 29 | sorong
# Processing Record 36 of Set 29 | kedrovyy
# Processing Record 37 of Set 29 | gwadar
# Processing Record 38 of Set 29 | faridnagar
# Processing Record 39 of Set 29 | saulkrasti
# Processing Record 40 of Set 29 | saint-pierre
# Processing Record 41 of Set 29 | debre sina
# Processing Record 42 of Set 29 | ludvika
# Processing Record 43 of Set 29 | kaura namoda
# Processing Record 44 of Set 29 | resistencia
# Processing Record 45 of Set 29 | aktash
# Processing Record 46 of Set 29 | lar
# Processing Record 47 of Set 29 | okakarara
# Processing Record 48 of Set 29 | dekalb
# Processing Record 49 of Set 29 | reconquista
# Processing Record 50 of Set 29 | omsukchan
# Processing Record 1 of Set 30 | khasan
# Processing Record 2 of Set 30 | frutal
# Processing Record 3 of Set 30 | abha
# Processing Record 4 of Set 30 | pinega
# Processing Record 5 of Set 30 | sterling
# Processing Record 6 of Set 30 | portsmouth
# Processing Record 7 of Set 30 | kavieng
# Processing Record 8 of Set 30 | homer
# Processing Record 9 of Set 30 | macusani
# Processing Record 10 of Set 30 | batagay-alyta
# Processing Record 11 of Set 30 | areni
# Processing Record 12 of Set 30 | mullaitivu
# City not found. Skipping...
# Processing Record 13 of Set 30 | tevaitoa
# Processing Record 14 of Set 30 | bermejo
# Processing Record 15 of Set 30 | sendhwa
# Processing Record 16 of Set 30 | oranjemund
# Processing Record 17 of Set 30 | kumluca
# Processing Record 18 of Set 30 | lubao
# Processing Record 19 of Set 30 | svolvaer
# Processing Record 20 of Set 30 | bantry
# Processing Record 21 of Set 30 | hatillo
# Processing Record 22 of Set 30 | ivanovka
# Processing Record 23 of Set 30 | gawler
# Processing Record 24 of Set 30 | linqiong
# Processing Record 25 of Set 30 | barbar
# City not found. Skipping...
# Processing Record 26 of Set 30 | pala
# Processing Record 27 of Set 30 | kaolinovo
# Processing Record 28 of Set 30 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 30 | teya
# Processing Record 30 of Set 30 | sao gabriel
# Processing Record 31 of Set 30 | lazaro cardenas
# Processing Record 32 of Set 30 | grand-santi
# Processing Record 33 of Set 30 | honningsvag
# Processing Record 34 of Set 30 | karasjok
# Processing Record 35 of Set 30 | kolondieba
# Processing Record 36 of Set 30 | berdigestyakh
# Processing Record 37 of Set 30 | karpathos
# Processing Record 38 of Set 30 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 39 of Set 30 | villarrica
# Processing Record 40 of Set 30 | anadyr
# Processing Record 41 of Set 30 | tigzirt
# Processing Record 42 of Set 30 | la paz
# Processing Record 43 of Set 30 | tabou
# Processing Record 44 of Set 30 | chapada dos guimaraes
# Processing Record 45 of Set 30 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 30 | baker city
# Processing Record 47 of Set 30 | madawaska
# Processing Record 48 of Set 30 | victoria point
# Processing Record 49 of Set 30 | dryden
# Processing Record 50 of Set 30 | kansanshi
# Processing Record 1 of Set 31 | roma
# Processing Record 2 of Set 31 | byron bay
# Processing Record 3 of Set 31 | topolobampo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_count = len(city_data)
city_count
# Out:
# 697

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City  Cloudiness Country Current Description  \
# 0  Saint-Philippe          49      RE    scattered clouds
# 1            Chuy           1      UY           clear sky
# 2         Angoche           0      MZ           clear sky
# 3    Punta Arenas         100      CL     overcast clouds
# 4            Hope           7      US           clear sky
#
#                   Date  Humidity      Lat      Lng  Max Temp  Wind Speed
# 0  2022-07-14 02:44:42        80 -21.3585  55.7679     63.99       12.21
# 1  2022-07-14 02:44:43        91 -33.6971 -53.4616     45.63        7.23
# 2  2022-07-14 02:44:43        74 -16.2325  39.9086     70.05        7.83
# 3  2022-07-14 02:44:11        75 -53.1500 -70.9167     37.51       17.27
# 4  2022-07-14 02:44:44        65  33.6671 -93.5916     84.25        8.84

# %%
#reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

#call the new df
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                       City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Saint-Philippe      RE -21.3585   55.7679     63.99        80
# 1                     Chuy      UY -33.6971  -53.4616     45.63        91
# 2                  Angoche      MZ -16.2325   39.9086     70.05        74
# 3             Punta Arenas      CL -53.1500  -70.9167     37.51        75
# 4                     Hope      US  33.6671  -93.5916     84.25        65
# 5                 Plouzane      FR  48.3833   -4.6167     59.18        97
# 6              Port Alfred      ZA -33.5906   26.8910     54.18        73
# 7               Vila Velha      BR -20.3297  -40.2925     70.95        88
# 8          Fort-Shevchenko      KZ  44.5086   50.2630     85.86        36
# 9                     Lasa      IT  46.6166   10.7002     68.88        66
# 10                Victoria      HK  22.2855  114.1577     91.33        75
# 11                  Lingao      CN  19.9103  109.6859     87.42        71
# 12                Bengkulu      ID  -3.8004  102.2655     83.30        70
# 13                Cidreira      BR -30.1811  -50.2056     57.99        82
# 14                Sisimiut      GL  66.9395  -53.6735     45.63        82
# 15                   Kenai      US  60.5544 -151.2583     63.03        79
# 16                  Castro      BR -24.7911  -50.0119     52.45        96
# 17                  Sabang      ID   5.8933   95.3214     82.54        78
# 18                 Dudinka      RU  69.4058   86.1778     58.62        49
# 19                   Pevek      RU  69.7008  170.3133     39.13        77
# 20               Hay River      CA  60.8156 -115.7999     66.18        45
# 21             New Norfolk      AU -42.7826  147.0587     54.91        80
# 22             Deputatskiy      RU  69.3000  139.9000     52.93        63
# 23                 Ushuaia      AR -54.8000  -68.3000     33.46        80
# 24                   Mecca      SA  21.4267   39.8261     83.17        52
# 25           Marsh Harbour      BS  26.5412  -77.0636     83.14        76
# 26                 Bourail      NC -21.5667  165.4833     69.44        76
# 27               Nhulunbuy      AU -12.2333  136.7667     77.61        61
# 28                 Mataura      NZ -46.1927  168.8643     46.47        91
# 29                 Rikitea      PF -23.1203 -134.9692     70.61        79
# ..                     ...     ...      ...       ...       ...       ...
# 667                 Bantry      IE  51.6833   -9.4500     54.79        92
# 668                Hatillo      PR  18.4863  -66.8254     79.84        94
# 669               Ivanovka      KG  42.8878   75.0850     78.87        31
# 670                 Gawler      AU -34.6000  138.7333     58.96        64
# 671               Linqiong      CN  30.4159  103.4609     83.93        80
# 672                   Pala      TD   9.3642   14.9046     73.31        81
# 673              Kaolinovo      BG  43.6167   27.1167     59.88        49
# 674                   Teya      RU  60.3778   92.6267     62.51        42
# 675            Sao Gabriel      BR -30.3364  -54.3200     50.65        80
# 676        Lazaro Cardenas      MX  17.9583 -102.2000     79.38        84
# 677            Grand-Santi      GF   4.2500  -54.3833     72.72        99
# 678            Honningsvag      NO  70.9821   25.9704     55.15        94
# 679               Karasjok      NO  69.4719   25.5112     59.63        97
# 680             Kolondieba      ML  11.0882   -6.8926     75.47        76
# 681          Berdigestyakh      RU  62.0989  126.6992     62.82        99
# 682              Karpathos      GR  35.5070   27.2132     71.56        78
# 683             Villarrica      PY -25.7500  -56.4333     60.76        89
# 684                 Anadyr      RU  64.7500  177.4833     55.90        82
# 685                Tigzirt      DZ  36.8886    4.1198     73.69        55
# 686                 La Paz      BO -16.5000  -68.1500     42.33        83
# 687                  Tabou      CI   4.4230   -7.3528     75.47        81
# 688  Chapada Dos Guimaraes      BR -15.4606  -55.7497     68.27        39
# 689             Baker City      US  44.7749 -117.8344     74.91        35
# 690              Madawaska      US  47.3561  -68.3288     63.70        67
# 691         Victoria Point      AU -27.5833  153.3000     68.14        54
# 692                 Dryden      CA  49.7833  -92.7503     59.79        66
# 693              Kansanshi      ZM -12.0951   26.4273     49.39        79
# 694                   Roma      US  43.2128  -75.4557     66.51        95
# 695              Byron Bay      AU -28.6500  153.6167     63.95        69
# 696            Topolobampo      MX  25.6000 -109.0500     82.31        57
#
#      Cloudiness  Wind Speed Current Description
# 0            49       12.21    scattered clouds
# 1             1        7.23           clear sky
# 2             0        7.83           clear sky
# 3           100       17.27     overcast clouds
# 4             7        8.84           clear sky
# 5             0        8.05           clear sky
# 6             0        4.00           clear sky
# 7            75        1.14       broken clouds
# 8             5       11.70           clear sky
# 9            98        2.37     overcast clouds
# 10           94        5.99     overcast clouds
# 11           25        9.51    scattered clouds
# 12           32        2.39    scattered clouds
# 13           12       20.69          few clouds
# 14           67        7.23       broken clouds
# 15          100       14.97     overcast clouds
# 16          100        7.85     overcast clouds
# 17           99       14.65          light rain
# 18           31        6.49    scattered clouds
# 19           92       13.87     overcast clouds
# 20           74        4.61       broken clouds
# 21          100        1.01          light rain
# 22          100        8.97     overcast clouds
# 23           40        9.22    scattered clouds
# 24           73        2.57       broken clouds
# 25           43       11.92    scattered clouds
# 26          100       11.21     overcast clouds
# 27           40       21.85    scattered clouds
# 28           54        5.10       broken clouds
# 29           93        7.20          light rain
# ..          ...         ...                 ...
# 667          20        3.31          few clouds
# 668          83        1.99       broken clouds
# 669           0        4.54           clear sky
# 670           4        3.02           clear sky
# 671          85        4.32     overcast clouds
# 672         100        4.65     overcast clouds
# 673          35        5.41    scattered clouds
# 674          50        3.27    scattered clouds
# 675          35       13.38       moderate rain
# 676         100        3.78     overcast clouds
# 677         100        1.92     overcast clouds
# 678         100        0.00     overcast clouds
# 679         100        5.21     overcast clouds
# 680          75        4.61       broken clouds
# 681         100        5.17       moderate rain
# 682           0       26.46           clear sky
# 683          97        5.86     overcast clouds
# 684          75        8.95       broken clouds
# 685           0        7.27           clear sky
# 686           8        1.16           clear sky
# 687         100        7.25     overcast clouds
# 688          63        5.73       broken clouds
# 689           0       11.50           clear sky
# 690         100        3.44     overcast clouds
# 691          19        5.99          few clouds
# 692           1        4.94           clear sky
# 693           6        3.76           clear sky
# 694          75        3.00       broken clouds
# 695          84       19.35       broken clouds
# 696         100        4.61     overcast clouds
#
# [697 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
